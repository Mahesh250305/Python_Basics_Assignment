# %% [markdown]
# # Python Basics Assignment
# ### Name: Ghanghas Mahesh
# ### Date: 21-02-2016

# %% [markdown]
# ## Question 1 - Simple Messsage
# store a message in a variable and print it.

# %%
message = "Welcome to Python!"
print(message)
# Out:
# Welcome to Python!

# %% [markdown]
# ## Question 2 -Changing Message
# store a message, print it, then change it and print again.

# %%
message = " I love coding."
print(message)

message = "Python is amazing."
print(message)
# Out:
#  I love coding.
# Python is amazing.

# %% [markdown]
# ## Question 3 - Personal Message
# store a person's name and print a personalized message.

# %%
name = "Mahesh"
print(f"Hello {name}, would you like to learn some python today?")
# Out:
# Hello Mahesh, would you like to learn some python today?

# %% [markdown]
# ## Question 4 - Famous Quote
# print a quote and the author's name.

# %%
print('A. P. J. Abdul Kalam once said, "Dream is not what you see in sleep, it is the thing which doesn’t let you sleep."')
# Out:
# A. P. J. Abdul Kalam once said, "Dream is not what you see in sleep, it is the thing which doesn’t let you sleep."

# %% [markdown]
# ## Question 5 - Famous Quote Using Variable
# Store the author's name in a variable and print the quote.

# %%
famous_person = "A. P. J. Abdul Kalam"
message = famous_person + ' once said, "Dream is not what you see in sleep, it is the thing which doesn’t let you sleep."'
print(message)
# Out:
# A. P. J. Abdul Kalam once said, "Dream is not what you see in sleep, it is the thing which doesn’t let you sleep."

# %% [markdown]
# ## Question 6 – Number 8
# Perform addition, subtraction, multiplication, and division that result in 8.

# %%
print(5 + 3)
print(10 - 2)
print(4 * 2)
print(16/2)
# Out:
# 8
# 8
# 8
# 8.0

# %% [markdown]
# ## Question 7 – Favorite Number
# Store your favorite number and print a message.

# %%
favorite_number = 7
print("My favorite number is", favorite_number)
# Out:
# My favorite number is 7

# %% [markdown]
# ## Question 8 – Comments in Programs
# Choose two programs written earlier and add at least one comment explaining what the program does.

# %%
# This program prints a simple welcome message
message = "Welcome to Python!"
print(message)


# This program performs operations that result in number 8
print(5 + 3)
print(10 - 2)
print(4 * 2)
print(16 / 2)
# Out:
# Welcome to Python!
# 8
# 8
# 8
# 8.0

# %% [markdown]
# ## Question 9 – Names in a List
# Store the names of a few friends in a list and print each name by accessing each element.

# %%
names = ["Rahul", "Amit", "Suresh", "Vikas", "Satish", "Ravi", "Virender"]

for name in names:
    print(name)
# Out:
# Rahul
# Amit
# Suresh
# Vikas
# Satish
# Ravi
# Virender

# %% [markdown]
# ## Question 10 – Personalized Messages
# Use the list from Question 9 and print a personalized message for each friend.

# %%
names = ["Rahul", "Amit", "Suresh", "Vikas", "Satish", "Ravi", "Virender"]

for name in names:
    print("Hello " + name + ", hope you are doing well!")
# Out:
# Hello Rahul, hope you are doing well!
# Hello Amit, hope you are doing well!
# Hello Suresh, hope you are doing well!
# Hello Vikas, hope you are doing well!
# Hello Satish, hope you are doing well!
# Hello Ravi, hope you are doing well!
# Hello Virender, hope you are doing well!

# %% [markdown]
# ## Question 11 – Favorite Mode of Transportation
# Create a list of favorite vehicles and print statements about them.

# %%
vehicles = ["Yamaha R15 bike", "Hyundai Verna", "Royal Enfield bike"]

for vehicle in vehicles:
    print("I would like to own a " + vehicle + ".")
# Out:
# I would like to own a Yamaha R15 bike.
# I would like to own a Hyundai Verna.
# I would like to own a Royal Enfield bike.

# %% [markdown]
# ---
# ### Assignment Completed Successfully ✅
# ### Submitted by: Ghanghas Mahesh
